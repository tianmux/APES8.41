# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import struct
import sys
from array import array
import itertools
import os
from scipy import signal
from scipy.optimize import curve_fit
import subprocess
import shutil
#from scipy.signal import find_peaks
import pandas as pd
pi = np.pi
clight = 299792458
E0Au = 196.9665687*931.5e6
E0Elec = 0.51099895000e6
clight = 299792458

# %%
def get_folders(folders,cwd):
    new_folders = []
    for folder in folders:
        if os.path.isdir(os.path.join(cwd,folder)):
            print(folder)
            new_folders.append(folder)
    return new_folders

# %%
#os.chdir('/home/txin/Dropbox/code/Cpp/APES_pack/APES8.4/bench/')
working_folder = '/home/txin/Dropbox/code/Cpp/CBI_Iterative/bench/1RF/APES/case1/'
#working_folder = '/media/dataHD/APES_sim_data/CBI/APES/case19_7_scan/'
home0 = os.getcwd()
home1 = os.path.join(home0,working_folder)
cwd = working_folder#os.path.join(home0,working_folder)

# %%
folders = os.listdir(cwd);
new_folders = get_folders(folders,cwd);
new_folders = np.sort(new_folders);


#get the starting index in the folder name string that represent the substring of current
i_start_current = new_folders[0].find('Idc')+3

#get the starting index in the folder name string that represent the substring of loading angle
i_start_thetaL = new_folders[0].find('ThetaL1')+6

#get the starting index in the folder name string that represent the sbustring of delay
i_start_delay = new_folders[0].find('delay')+5
##get the starting index in the folder name string that represent the sbustring of gain
i_start_gain = new_folders[0].find('gain')+4


current = [float(folder[folder.find('Idc')+3:folder.find('Idc')+3+4]) for folder in new_folders]
thetaL = [float(folder[folder.find('ThetaL')+6:folder.find('ThetaL')+6+3]) for folder in new_folders]

#delay = [float(folder[folder.find('delay')+5:folder.find('delay')+5+3]) for folder in new_folders]
gain = [float(folder[folder.find('gain')+4:folder.find('gain')+4+3]) for folder in new_folders]
# Out:
# 000014000000nmacro1_nBin333_Idc2.50A_ThetaL4.0degree_delay0.000us_gain0.00_0.00
# 000003000000nmacro1_nBin333_Idc2.50A_ThetaL-7.0degree_delay0.000us_gain0.00_0.00
# 000001000000nmacro1_nBin333_Idc2.50A_ThetaL-9.0degree_delay0.000us_gain0.00_0.00
# 000010000000nmacro1_nBin333_Idc2.50A_ThetaL0.0degree_delay0.000us_gain0.00_0.00
# 000009000000nmacro1_nBin333_Idc2.50A_ThetaL-1.0degree_delay0.000us_gain0.00_0.00
# 000005000000nmacro1_nBin333_Idc2.50A_ThetaL-5.0degree_delay0.000us_gain0.00_0.00
# 000017000000nmacro1_nBin333_Idc2.50A_ThetaL7.0degree_delay0.000us_gain0.00_0.00
# 000008000000nmacro1_nBin333_Idc2.50A_ThetaL-2.0degree_delay0.000us_gain0.00_0.00
# 000004000000nmacro1_nBin333_Idc2.50A_ThetaL-6.0degree_delay0.000us_gain0.00_0.00
# 000006000000nmacro1_nBin333_Idc2.50A_ThetaL-4.0degree_delay0.000us_gain0.00_0.00
# 000019000000nmacro1_nBin333_Idc2.50A_ThetaL9.0degree_delay0.000us_gain0.00_0.00
# 000011000000nmacro1_nBin333_Idc2.50A_ThetaL1.0degree_delay0.000us_gain0.00_0.00
# 000007000000nmacro1_nBin333_Idc2.50A_ThetaL-3.0degree_delay0.000us_gain0.00_0.00
# 000018000000nmacro1_nBin333_Idc2.50A_ThetaL8.0degree_delay0.000us_gain0.00_0.00
# 000000000000nmacro1_nBin333_Idc2.50A_ThetaL-10.0degree_delay0.000us_gain0.00_0.00
# 000013000000nmacro1_nBin333_Idc2.50A_ThetaL3.0degree_delay0.000us_gain0.00_0.00
# 000015000000nmacro1_nBin333_Idc2.50A_ThetaL5.0degree_delay0.000us_gain0.00_0.00
# 000012000000nmacro1_nBin333_Idc2.50A_ThetaL2.0degree_delay0.000us_gain0.00_0.00
# 000016000000nmacro1_nBin333_Idc2.50A_ThetaL6.0degree_delay0.000us_gain0.00_0.00
# 000002000000nmacro1_nBin333_Idc2.50A_ThetaL-8.0degree_delay0.000us_gain0.00_0.00

# %%
thetaL1 = np.unique(thetaL)

# %%
inputfile = 'input.txt'
temppath = os.path.join(cwd,new_folders[0])
inputfile = os.path.join(temppath,inputfile)
tempinput = {}
with open(inputfile) as inputfile:
    for line in inputfile:
        if len(line.split())>1:
            tempinput[line.split()[0]] = line.split()[1:]
for i in tempinput:
    for j in range(len(tempinput[i])):
        tempinput[i][j] = float(tempinput[i][j])

# %%
nRF = int(tempinput['nRF'][0])
nRF1 = int(tempinput['nRF1'][0])
nRF2 = int(tempinput['nRF2'][0])
nRFc = int(tempinput['nRFc'][0])

E0Au = 196.9665687*931.5e6
E0Elec = 0.51099895000e6
nTurns = int(tempinput['n_turns'][0])
nDynamic = int(tempinput['n_dynamicOn'][0])
nfill = int(tempinput['n_fill'][0])
n_q_ramp = int(tempinput['n_q_ramp'][0])
NpRF = int(tempinput['N_bins'][0])
h = [int(i) for i in tempinput['h']]
detune_ini = np.array([i for i in tempinput['detune_ini']])
detune_final = np.array([i for i in tempinput['detune_final']])

step = int(tempinput['step_store'][0])
fill_step = int(tempinput['fill_step'][0])
nBeam = int(tempinput['nBeam'][0])
beam_shift = int(tempinput['beam_shift'][0])
nBunch = int(tempinput['n_bunches'][0])
nPar = int(tempinput['Npar'][0])
NperBunch = int(tempinput['NperBunch'][0])
nTot = nBunch*nPar*nBeam
Gamma0 = tempinput['Gamma'][0]
Rring = tempinput['R'][0]
n_record = nTurns/step
clight = 299792458
beta = np.sqrt(1-1/Gamma0**2)
T0 = 2*np.pi*Rring/(clight*beta)
f0 = 1/T0
V0 = [i for i in tempinput['Vref_I']]
V0Q = [i for i in tempinput['Vref_Q']]
II = [i for i in tempinput['Iref_I']]
IQ = [i for i in tempinput['Iref_Q']]
mainRF = int(tempinput['mainRF'][0])
t_rad_long = tempinput['t_rad_long'][0]
if int(tempinput['type'][0]==2):
    atomicZ = 79
    Ek = Gamma0*E0Au
else:
    atomicZ =1
if int(tempinput['type'][0]==1):  
    Ek = Gamma0*E0Elec
    
GMTSQ = tempinput['GMTSQ'][0]
Ek_damp = tempinput['Ek_damp'][0]

eta = 1/GMTSQ-1/Gamma0**2
if nRF ==1:
    Qs = np.sqrt(h[mainRF]*atomicZ*np.abs(V0[mainRF])*eta/(2*np.pi*Ek))
elif nRF == 2 :
    Qs = np.sqrt(h[mainRF]*atomicZ*np.abs(V0[mainRF]+V0[1])*eta/(2*np.pi*Ek))

omegarf = 2*np.pi*(np.array(h)*f0)
omegac = 2*np.pi*(np.array(h)*f0+detune_final)
Trf = 2*np.pi/omegarf
RoQ = [i for i in tempinput['RoQ']]
QL = [i for i in tempinput['QL']]
R = [RoQ[i]*QL[i] for i in range(nRF)]

Th = 2*np.pi/omegarf[0]
dthat =Th/NpRF

pattern = 'd'+'dd'*nBeam+3*nRF*'d'
n_stride = 1+2*nBeam+3*nRF
stride = len(pattern)*8
test = array('d')
bucket_height = 2*Qs/(h[mainRF]*eta)


print(Qs)
print(bucket_height)
# Out:
# 0.05
# 0.0148960608573

# %%
# iterative solver
def Zparallel(Rsh, QL, omega0, omega,gain):
    return Rsh/(1+gain)*omega/(omega+1j*QL/(1+gain)*(omega0-omega**2/omega0)) # using the convention from A. Chao's book

r0 = (1*1.6e-19)**2/(1*9.10938356e-31*3e8*3e8)
sigz = 7e-3 # rms bunch length
sigt = sigz/clight
sigPhi = 2*pi*f0*sigt
pmax = 1*100 # number of samples in frequency domain

N_mode = 2 # number of Coupled bunch mode to look
mu_danger = 0 # the mode we think is the most dangers
mus = np.array([i for i in range(N_mode)])

N_m = 2 # number of longitudinal modes ( 1 means dipole, 2 means quadruple)
ms = np.array([i for i in range(N_m)])

omegas = Qs*f0*2*pi
ps = np.array([float(i) for i in range(-pmax,pmax+1)])
p_M_omega0 = ps*nBunch*2*np.pi*f0
print("fs = ",omegas/2/pi)
omegas = Qs*2*pi*f0

N_thetaL1 = len(thetaL1)
N_thetaL2 = 1#len(thetaL2)

delta_omega_Re_Iter = np.ndarray([N_m,N_mode,N_thetaL1,N_thetaL2])
delta_omega_Im_Iter = np.ndarray([N_m,N_mode,N_thetaL1,N_thetaL2])

N_OMEGA_guss = 150
phistart = -75/180*pi
phiend = 75/180*pi
dphi = (phiend-phistart)/N_OMEGA_guss
OMEAG_ini = [omegas*np.exp(1j*phistart)*np.exp(1j*i*dphi) for i in range(N_OMEGA_guss)]

m = 1

def F(Omega,ps,mu,m,nRF,R,QL,omegac,nBunch, NperBunch,r0,eta,Gamma0,T0,Qs,f0,gain,sigPhi):
    omega0 = f0*2*pi
    fact = np.math.factorial(m-1)
    nMmu = ps*nBunch+mu
    omegasamp = ((ps*nBunch+mu)*2*np.pi*f0+Omega)
    Zs = np.array([Zparallel(R[i],QL[i],omegac[i],omegasamp,gain) for i in range(nRF)])
    factor = nBunch*NperBunch*r0*eta/(Gamma0*T0**2)/T0*4*pi*(m/fact)/(2**m)*sigPhi**(2*m-2)
    return (Omega**2-(1j*factor*np.sum((omegasamp/omega0)**(2*m-1)*Zs*np.exp(-nMmu**2*sigPhi**2))+(Qs*f0*2*pi)**2))/(Qs*f0*2*pi)**2

def SolveOmega(Omega,ps,mu,m,nRF,R,QL,omegac,nBunch, NperBunch,r0,eta,Gamma0,T0,Qs,f0,maxIter,accu,gain,sigPhi):
    nIter = 0
    maxstep = 1000
    # initial values
    OmegaR = np.real(Omega)
    OmegaI = np.imag(Omega)
    Omegat1 = Omega
    Omegat2 = Omegat1
    # step size
    sig1 = 1e-7
    sig2 = 1e-7*1j
    Err = F(Omega,ps,mu,m,nRF,R,QL,omegac,nBunch, NperBunch,r0,eta,Gamma0,T0,Qs,f0,gain,sigPhi)
    Err_store = Err
    while(np.abs(Err)>accu and nIter<maxIter):
        OmegaR = np.real(Omega)
        OmegaI = np.imag(Omega)
        Omegat1 = Omega
        Err = F(Omega,ps,mu,m,nRF,R,QL,omegac,nBunch, NperBunch,r0,eta,Gamma0,T0,Qs,f0,gain,sigPhi)
        F1 = F(Omega+sig1,ps,mu,m,nRF,R,QL,omegac,nBunch, NperBunch,r0,eta,Gamma0,T0,Qs,f0,gain,sigPhi) # change OmegaRe by a small step
        F2 = F(Omega+sig2,ps,mu,m,nRF,R,QL,omegac,nBunch, NperBunch,r0,eta,Gamma0,T0,Qs,f0,gain,sigPhi) # change OmegaIm by a small step
        Fre = np.real(Err)
        Fim = np.imag(Err)
        F1re = np.real(F1)
        F1im = np.imag(F1)
        F2re = np.real(F2)
        F2im = np.imag(F2)
        # approximate the Jacobian
        dF11 = (F1re-Fre)/np.abs(sig1)
        dF12 = (F2re-Fre)/np.abs(sig1)
        dF21 = (F1im-Fim)/np.abs(sig2)
        dF22 = (F2im-Fim)/np.abs(sig2)
        
        det = dF11*dF22-dF12*dF21
        # inverse the Jacobian
        dF11inv = dF22/det
        dF12inv = -dF12/det
        dF21inv = -dF21/det
        dF22inv = dF11/det
        dFR = Fre*dF11inv+Fim*dF12inv
        if dFR >maxstep:
            OmegaR -= maxstep
        else:
            OmegaR -= dFR
        dFI = Fre*dF21inv+Fim*dF22inv
        if dFI > maxstep:
            OmegaI -= maxstep
        else:
            OmegaI -= dFI
        
        Omega = OmegaR+OmegaI*1j
        nIter += 1
        #if np.abs(Omega-Omegat2) < 1e-7:
        #    print("Omega  : ", Omega)
        #    print("Omega1 : ", Omegat1)
        #    print("Omega2 : ", Omegat2)
        #    print("Err    : ", Err)
        #    Omega=(Omegat2+Omegat1)/2
        #else:
        #    Omegat2 = Omegat1
        
        Err_store = Err
    if nIter == maxIter:
        print("Maxed out!","...","Err = ",Err)
        print("OMEGA = ",Omega)
        return 1-1e100*1j
    #print(np.abs(Err))
    return Omega
    print(Omega)
    print(nIter)
# Out:
# fs =  3909.81441814

# %%
# Iteratively solve:

inputfn = 'input.txt'
for m in ms:
    for mu in mus:
        qidx=0
        for folder in new_folders[:]:
            print(folder)
            os.chdir(os.path.join(home1,folder))
            cwd = os.getcwd()
            inputfile = os.path.join(cwd,inputfn)
            tempinput = {}
            with open(inputfile) as inputfile:
                for line in inputfile:
                    if len(line.split())>1:
                        tempinput[line.split()[0]] = line.split()[1:]
            for i in tempinput:
                for j in range(len(tempinput[i])):
                    tempinput[i][j] = float(tempinput[i][j])
            nRF = int(tempinput['nRF'][0])
            nRF1 = int(tempinput['nRF1'][0])
            nRF2 = int(tempinput['nRF2'][0])
            nRFc = int(tempinput['nRFc'][0])

            nTurns = int(tempinput['n_turns'][0])
            nfill = int(tempinput['n_fill'][0])
            n_q_ramp = int(tempinput['n_q_ramp'][0])
            NpRF = int(tempinput['N_bins'][0])
            h = [int(i) for i in tempinput['h']]
            detune_ini = np.array([i for i in tempinput['detune_ini']])
            detune_final = np.array([i for i in tempinput['detune_final']])

            step = int(tempinput['step_store'][0])
            fill_step = int(tempinput['fill_step'][0])
            nBeam = int(tempinput['nBeam'][0])
            beam_shift = int(tempinput['beam_shift'][0])
            nBunch = int(tempinput['n_bunches'][0])
            nPar = int(tempinput['Npar'][0])
            NperBunch = int(tempinput['NperBunch'][0])
            nTot = nBunch*nPar*nBeam
            Gamma0 = tempinput['Gamma'][0]
            Rring = tempinput['R'][0]
            n_record = nTurns/step
            beta = np.sqrt(1-1/Gamma0**2)
            T0 = 2*np.pi*Rring/(clight*beta)
            f0 = 1/T0
            V0 = [i for i in tempinput['Vref_I']]
            V0Q = [i for i in tempinput['Vref_Q']]
            II = [i for i in tempinput['Iref_I']]
            IQ = [i for i in tempinput['Iref_Q']]
            mainRF = int(tempinput['mainRF'][0])
            Pbeam = tempinput['Prad'][0]
            if int(tempinput['type'][0]==2):
                atomicZ = 79
                Ek = Gamma0*E0Au
            else:
                atomicZ =1
            if int(tempinput['type'][0]==1):  
                Ek = Gamma0*E0Elec

            GMTSQ = tempinput['GMTSQ'][0]
            Ek_damp = tempinput['Ek_damp'][0]

            eta = 1/GMTSQ-1/Gamma0**2
            if nRF ==1:
                Qs = np.sqrt(h[mainRF]*atomicZ*np.abs(V0[mainRF])*eta/(2*np.pi*Ek))
            elif nRF == 2 :
                Qs = np.sqrt(h[mainRF]*atomicZ*np.abs(V0[mainRF]+V0[1])*eta/(2*np.pi*Ek))
            print("Qs: ",Qs)
            omegarf = 2*np.pi*(np.array(h)*f0)
            omegac = 2*np.pi*(np.array(h)*f0+detune_final)
            #omegac = omegac+np.array([200*2*pi,0])
            Trf = 2*np.pi/omegarf
            RoQ = [i for i in tempinput['RoQ']]
            QL = [i for i in tempinput['QL']]
            R = [RoQ[i]*QL[i] for i in range(nRF)]

            Th = 2*np.pi/omegarf[0]
            dthat =Th/NpRF

            pattern = 'd'+'dd'*nBeam+3*nRF*'d'
            n_stride = 1+2*nBeam+3*nRF
            stride = len(pattern)*8
            test = array('d')
            print("dfc: ",omegac/2/pi-f0*h[0])
            print("NperBunch: ",NperBunch/1e11)
            print("nBunch: ",nBunch)

            #print("QL: ",QL)
            #print("R: ",R)
            maxOMEGAIM = -1e360            
            print("Current mode : ",m+1,',',mu)

            for Omega in OMEAG_ini:
                t_omega = Omega*1.0
                temp = SolveOmega(Omega,ps,nBunch-mu,m+1,nRF,R,QL,omegac,nBunch, NperBunch,r0,eta,Gamma0,T0,Qs,f0,10000,1e-6,gain[qidx],sigPhi)
                if np.imag(temp)>maxOMEGAIM:
                    #print("Found a bigger one : ",t_omega,np.arctan(np.imag(t_omega)/np.real(t_omega))/pi*180)
                    print("Found a bigger one : ",temp)
                    maxOMEGAIM = np.imag(temp)
                    delta_omega_Re_Iter[m][mu][int(qidx/N_thetaL2)][qidx%N_thetaL2] = np.real(temp)
                    delta_omega_Im_Iter[m][mu][int(qidx/N_thetaL2)][qidx%N_thetaL2] = np.imag(temp)
            print("---------------------")
            print(qidx,';',(delta_omega_Re_Iter[m][mu][int(qidx/N_thetaL2)][qidx%N_thetaL2]-omegas)/2/pi,delta_omega_Im_Iter[m][mu][int(qidx/N_thetaL2)][qidx%N_thetaL2])
            print("---------------------")
            qidx+=1
# Out:
# 000000000000nmacro1_nBin333_Idc2.50A_ThetaL-10.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19196.24063283]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.00266056862477-6916.74936187j)
# Found a bigger one :  (0.00202327260449-6916.74564401j)
# Found a bigger one :  (0.00567679565241-6916.74395214j)
# Found a bigger one :  (-0.00271241743853+5139.72092346j)
# Found a bigger one :  (0.00945692788243+5139.72573529j)
# Found a bigger one :  (0.0147205673128+5139.73534531j)
# Found a bigger one :  (0.0148466562051+5139.73546897j)
# ---------------------
# 0 ; -3909.81205522 5139.73546897
# ---------------------
# 000001000000nmacro1_nBin333_Idc2.50A_ThetaL-9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19321.34517914]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.00292027987428-6584.27468052j)
# Found a bigger one :  (-0.0544987000849-6584.22361361j)
# Found a bigger one :  (-0.0064957782279+4838.18316365j)
# Found a bigger one :  (0.00298109623682+4838.18316365j)
# Found a bigger one :  (0.00780384112861+4838.1909586j)
# Found a bigger one :  (-0.00967571733269+4838.1928367j)
# ---------------------
# 1 ; -3909.81595808 4838.1928367
# ---------------------
# 000002000000nmacro1_nBin333_Idc2.50A_ThetaL-8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19445.75986254]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.00141662135377-6239.10716089j)
# Found a bigger one :  (-0.00321230523809-6239.10716086j)
# Found a bigger one :  (-0.00483264746468+4523.10807041j)
# Found a bigger one :  (-0.00423041155585+4523.10807041j)
# Found a bigger one :  (-0.0164799492347+4523.10807045j)
# Found a bigger one :  (0.00819431012372+4523.10807072j)
# Found a bigger one :  (0.00550610345541+4523.1109833j)
# ---------------------
# 2 ; -3909.81354181 4523.1109833
# ---------------------
# 000003000000nmacro1_nBin333_Idc2.50A_ThetaL-7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19569.56558514]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (-0.030414991006-5878.32176665j)
# Found a bigger one :  (-0.00849706215081-5878.29420857j)
# Found a bigger one :  (0.000867859557499-5878.29420852j)
# Found a bigger one :  (0.00319915298694-5878.29420852j)
# Found a bigger one :  (-0.00711190454683-5878.27725219j)
# Found a bigger one :  (0.00362014254617+4191.59018511j)
# Found a bigger one :  (0.00604524222226+4191.59018514j)
# Found a bigger one :  (0.00602110664599+4191.59018597j)
# Found a bigger one :  (-0.00436744517773+4191.59018692j)
# Found a bigger one :  (-0.0080561027598+4191.59018746j)
# Found a bigger one :  (-0.00175684341387+4191.59269363j)
# ---------------------
# 3 ; -3909.81469775 4191.59269363
# ---------------------
# 000004000000nmacro1_nBin333_Idc2.50A_ThetaL-6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19692.84172004]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.00724536275493-5497.88727604j)
# Found a bigger one :  (0.0127145114696+3839.72502543j)
# Found a bigger one :  (-0.0075225371051+3839.72502564j)
# Found a bigger one :  (-0.00460230607702+3839.72502566j)
# Found a bigger one :  (0.00455360205633+3839.72502571j)
# Found a bigger one :  (0.0119959009926+3839.72502791j)
# Found a bigger one :  (-0.0146315935926+3839.73311619j)
# Found a bigger one :  (0.00755334722881+3839.73600668j)
# Found a bigger one :  (0.0129380497891+3839.73878539j)
# ---------------------
# 4 ; -3909.81235898 3839.73878539
# ---------------------
# 000005000000nmacro1_nBin333_Idc2.50A_ThetaL-5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19815.66631979]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.0013914778612-5092.36668609j)
# Found a bigger one :  (-0.0281548375718-5092.31933012j)
# Found a bigger one :  (0.0104424186667+3462.03415927j)
# Found a bigger one :  (-0.00992104312505+3462.03416107j)
# Found a bigger one :  (-0.0110422364984+3462.03416472j)
# Found a bigger one :  (0.0225855137845+3462.04692191j)
# ---------------------
# 5 ; -3909.81082354 3462.04692191
# ---------------------
# 000006000000nmacro1_nBin333_Idc2.50A_ThetaL-4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19938.11631757]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.00243118229087-4653.55713293j)
# Found a bigger one :  (0.00567733913858-4653.55713285j)
# Found a bigger one :  (-0.0423921307319-4653.55712262j)
# Found a bigger one :  (-0.122430880342-4653.45233285j)
# Found a bigger one :  (-0.0161455374211+3050.38093354j)
# Found a bigger one :  (0.0118762723304+3050.38093375j)
# Found a bigger one :  (0.00819129155332+3050.38093408j)
# Found a bigger one :  (0.017979522441+3050.38094027j)
# Found a bigger one :  (0.0218440103723+3050.39358658j)
# Found a bigger one :  (0.0245056153578+3050.39512313j)
# ---------------------
# 6 ; -3909.81051795 3050.39512313
# ---------------------
# 000007000000nmacro1_nBin333_Idc2.50A_ThetaL-3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20060.26772255]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.00801486235385-4168.34248764j)
# Found a bigger one :  (-0.00778782942484-4168.34248734j)
# Found a bigger one :  (0.0112403697012+2591.68548781j)
# Found a bigger one :  (-0.0106867827987+2591.68548789j)
# Found a bigger one :  (-0.0171067818752+2591.68549106j)
# Found a bigger one :  (0.0193513692516+2591.68549107j)
# Found a bigger one :  (0.00440044412973+2591.68810061j)
# ---------------------
# 7 ; -3909.81371779 2591.68810061
# ---------------------
# 000008000000nmacro1_nBin333_Idc2.50A_ThetaL-2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20182.19581044]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.0115909996477-3612.99813942j)
# Found a bigger one :  (-0.450749112261-3612.63046351j)
# Found a bigger one :  (0.0365012504739+2062.25727768j)
# Found a bigger one :  (0.0244388234566+2062.25727897j)
# Found a bigger one :  (0.023102378281+2062.25727921j)
# Found a bigger one :  (-0.0165600203024+2062.25727982j)
# Found a bigger one :  (0.0228706998298+2062.28426543j)
# ---------------------
# 8 ; -3909.81077815 2062.28426543
# ---------------------
# 000009000000nmacro1_nBin333_Idc2.50A_ThetaL-1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20303.97530997]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (-0.0290024397204-2934.76778062j)
# Found a bigger one :  (-0.0403626726342+1409.37204264j)
# Found a bigger one :  (-0.0393044978986+1409.37205248j)
# Found a bigger one :  (-0.00471904951606+1409.37505276j)
# Found a bigger one :  (-0.0353726118144+1409.41532703j)
# ---------------------
# 9 ; -3909.82004786 1409.41532703
# ---------------------
# 000010000000nmacro1_nBin333_Idc2.50A_ThetaL0.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20425.68058711]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (0.0687982436955-1941.58960508j)
# Found a bigger one :  (0.0823340165241-1941.5896038j)
# Found a bigger one :  (0.0850562944894-1941.58960309j)
# Found a bigger one :  (-0.241347249914+440.998112417j)
# Found a bigger one :  (0.0178344545754+440.998142538j)
# Found a bigger one :  (0.0237504832506+440.998160175j)
# Found a bigger one :  (-0.0908178079656+441.058963305j)
# Found a bigger one :  (-0.0525427163062+441.065883134j)
# ---------------------
# 10 ; -3909.82278057 441.065883134
# ---------------------
# 000011000000nmacro1_nBin333_Idc2.50A_ThetaL1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20547.38582677]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (1358.85125286-738.152652902j)
# Found a bigger one :  (1358.85212885-738.137554412j)
# Found a bigger one :  (1358.85259537-738.13093323j)
# Found a bigger one :  (1358.8541556-738.102847861j)
# Found a bigger one :  (1358.85635958-738.064480308j)
# Found a bigger one :  (1358.77852718-738.039377161j)
# ---------------------
# 11 ; -3693.55809897 -738.039377161
# ---------------------
# 000012000000nmacro1_nBin333_Idc2.50A_ThetaL2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20669.16521358]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (2254.21567832-726.246789467j)
# Found a bigger one :  (2254.21570172-726.246549382j)
# Found a bigger one :  (2254.21583863-726.245008991j)
# Found a bigger one :  (2254.21587341-726.244770824j)
# Found a bigger one :  (2254.21588138-726.244692513j)
# Found a bigger one :  (2254.2197183-726.243828551j)
# Found a bigger one :  (2254.21622889-726.241050568j)
# Found a bigger one :  (2254.21793089-726.223279108j)
# Found a bigger one :  (2253.99674584-726.080029683j)
# Found a bigger one :  (2253.71799868-725.868131136j)
# ---------------------
# 12 ; -3551.12405831 -725.868131136
# ---------------------
# 000013000000nmacro1_nBin333_Idc2.50A_ThetaL3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20791.09311295]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (2878.91763572-714.574230144j)
# Found a bigger one :  (2878.91885168-714.57377568j)
# Found a bigger one :  (2878.91894384-714.57303075j)
# Found a bigger one :  (2878.91904813-714.572174716j)
# Found a bigger one :  (2878.90011418-714.55919855j)
# Found a bigger one :  (2878.89221779-714.553129809j)
# ---------------------
# 13 ; -3451.62449105 -714.553129809
# ---------------------
# 000014000000nmacro1_nBin333_Idc2.50A_ThetaL4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20913.24425352]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (3386.55966407-703.118258556j)
# Found a bigger one :  (3386.55142895-703.105715676j)
# Found a bigger one :  (3386.51848384-703.087298213j)
# Found a bigger one :  (3386.56549582-703.073912341j)
# ---------------------
# 14 ; -3370.82577937 -703.073912341
# ---------------------
# 000015000000nmacro1_nBin333_Idc2.50A_ThetaL5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21035.69391024]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (3824.32215353-691.857769742j)
# ---------------------
# 15 ; -3301.15464343 -691.857769742
# ---------------------
# 000016000000nmacro1_nBin333_Idc2.50A_ThetaL6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21158.5180915]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (4214.31343226-680.818180806j)
# Found a bigger one :  (4214.31356703-680.81745778j)
# Found a bigger one :  (4214.31140395-680.814729387j)
# Found a bigger one :  (4214.31439801-680.812715662j)
# Found a bigger one :  (4214.31453837-680.811977911j)
# Found a bigger one :  (4214.27983589-680.800161736j)
# ---------------------
# 16 ; -3239.09095068 -680.800161736
# ---------------------
# 000017000000nmacro1_nBin333_Idc2.50A_ThetaL7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21281.79372925]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (4568.99080132-669.950727772j)
# Found a bigger one :  (4568.99083845-669.95056082j)
# Found a bigger one :  (4568.99093446-669.950074231j)
# Found a bigger one :  (4568.99098431-669.949803298j)
# Found a bigger one :  (4568.99117906-669.948813079j)
# Found a bigger one :  (4568.98874691-669.948550738j)
# Found a bigger one :  (4568.99146524-669.947321364j)
# Found a bigger one :  (4568.99523876-669.946748434j)
# ---------------------
# 17 ; -3182.63624093 -669.946748434
# ---------------------
# 000018000000nmacro1_nBin333_Idc2.50A_ThetaL8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21405.59887499]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (4896.24643043-659.2609952j)
# Found a bigger one :  (4896.24665369-659.259949965j)
# Found a bigger one :  (4896.24667824-659.259832115j)
# Found a bigger one :  (4896.2473122-659.256777598j)
# Found a bigger one :  (4896.2405028-659.250833261j)
# ---------------------
# 18 ; -3130.55353955 -659.250833261
# ---------------------
# 000019000000nmacro1_nBin333_Idc2.50A_ThetaL9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21530.01290041]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 0
# Found a bigger one :  (5201.44914085-648.7381243j)
# Found a bigger one :  (5201.44937286-648.737066679j)
# Found a bigger one :  (5201.44598656-648.735499169j)
# Found a bigger one :  (5201.44762194-648.735108005j)
# Found a bigger one :  (5201.44985856-648.734879276j)
# Found a bigger one :  (5201.4451541-648.730512494j)
# ---------------------
# 19 ; -3081.97871064 -648.730512494
# ---------------------
# 000000000000nmacro1_nBin333_Idc2.50A_ThetaL-10.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19196.24063283]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25393.6179465+93.3084905991j)
# Found a bigger one :  (25393.6179474+93.3084907301j)
# Found a bigger one :  (25393.6179677+93.3084938359j)
# Found a bigger one :  (25393.6179718+93.3084944724j)
# Found a bigger one :  (25393.617999+93.3084986381j)
# Found a bigger one :  (25393.6181041+93.3085147135j)
# Found a bigger one :  (25393.6181841+93.3085236553j)
# ---------------------
# 0 ; 131.705438854 93.3085236553
# ---------------------
# 000001000000nmacro1_nBin333_Idc2.50A_ThetaL-9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19321.34517914]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25400.501211+94.0745640942j)
# Found a bigger one :  (25400.5012118+94.0745642238j)
# Found a bigger one :  (25400.5012354+94.0745674903j)
# Found a bigger one :  (25400.5012358+94.0745679001j)
# Found a bigger one :  (25400.5012583+94.0745713096j)
# Found a bigger one :  (25400.5013241+94.0745861152j)
# ---------------------
# 1 ; 132.800924599 94.0745861152
# ---------------------
# 000002000000nmacro1_nBin333_Idc2.50A_ThetaL-8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19445.75986254]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25407.3633285+94.8399850694j)
# Found a bigger one :  (25407.3633296+94.8399852371j)
# Found a bigger one :  (25407.363334+94.8399859199j)
# Found a bigger one :  (25407.3633617+94.8399901566j)
# Found a bigger one :  (25407.3633784+94.8399927635j)
# Found a bigger one :  (25407.3635114+94.8400131825j)
# Found a bigger one :  (25407.363561+94.8400161012j)
# ---------------------
# 2 ; 133.893083527 94.8400161012
# ---------------------
# 000003000000nmacro1_nBin333_Idc2.50A_ThetaL-7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19569.56558514]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25414.2086673+95.6052360679j)
# Found a bigger one :  (25414.2086711+95.6052366521j)
# Found a bigger one :  (25414.2086742+95.6052371269j)
# Found a bigger one :  (25414.2086764+95.6052374638j)
# Found a bigger one :  (25414.2086775+95.6052376351j)
# Found a bigger one :  (25414.2086874+95.605239153j)
# Found a bigger one :  (25414.2088515+95.6052602306j)
# ---------------------
# 3 ; 134.982545347 95.6052602306
# ---------------------
# 000004000000nmacro1_nBin333_Idc2.50A_ThetaL-6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19692.84172004]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25421.0415589+96.3707999258j)
# Found a bigger one :  (25421.0415598+96.3708000668j)
# Found a bigger one :  (25421.0415696+96.3708015848j)
# Found a bigger one :  (25421.0415891+96.3708045762j)
# Found a bigger one :  (25421.0416061+96.3708071753j)
# Found a bigger one :  (25421.0418689+96.3708433402j)
# ---------------------
# 4 ; 136.070053843 96.3708433402
# ---------------------
# 000005000000nmacro1_nBin333_Idc2.50A_ThetaL-5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19815.66631979]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25427.8661496+97.1371319912j)
# Found a bigger one :  (25427.8662578+97.137153207j)
# Found a bigger one :  (25427.8662666+97.1371545556j)
# Found a bigger one :  (25427.8662667+97.1371545736j)
# Found a bigger one :  (25427.8663071+97.1371608052j)
# Found a bigger one :  (25427.8663151+97.1371619826j)
# Found a bigger one :  (25427.8663188+97.1371626007j)
# Found a bigger one :  (25427.8664291+97.137177407j)
# Found a bigger one :  (25427.8664782+97.1371842862j)
# Found a bigger one :  (25427.8665058+97.1371866196j)
# ---------------------
# 5 ; 137.156228538 97.1371866196
# ---------------------
# 000006000000nmacro1_nBin333_Idc2.50A_ThetaL-4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19938.11631757]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25434.6870592+97.9047837149j)
# Found a bigger one :  (25434.6870618+97.9047841202j)
# Found a bigger one :  (25434.6870653+97.9047846656j)
# Found a bigger one :  (25434.6870657+97.9047847196j)
# Found a bigger one :  (25434.6871016+97.9047902273j)
# Found a bigger one :  (25434.6871149+97.9047923262j)
# Found a bigger one :  (25434.6871622+97.9047982958j)
# Found a bigger one :  (25434.6871608+97.904799409j)
# Found a bigger one :  (25434.6872458+97.9048124411j)
# Found a bigger one :  (25434.6872915+97.9048164633j)
# ---------------------
# 6 ; 138.241790304 97.9048164633
# ---------------------
# 000007000000nmacro1_nBin333_Idc2.50A_ThetaL-3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20060.26772255]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25441.5082107+98.674176602j)
# Found a bigger one :  (25441.508211+98.674176655j)
# Found a bigger one :  (25441.5082117+98.6741767617j)
# Found a bigger one :  (25441.5082434+98.6741816217j)
# Found a bigger one :  (25441.5082502+98.6741827096j)
# Found a bigger one :  (25441.5082531+98.6741831422j)
# Found a bigger one :  (25441.508258+98.6741839128j)
# Found a bigger one :  (25441.5082675+98.6741840379j)
# Found a bigger one :  (25441.508423+98.6742051409j)
# ---------------------
# 7 ; 139.327407091 98.6742051409
# ---------------------
# 000008000000nmacro1_nBin333_Idc2.50A_ThetaL-2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20182.19581044]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25448.3339553+99.4458205294j)
# Found a bigger one :  (25448.3339558+99.4458206142j)
# Found a bigger one :  (25448.3339917+99.4458261721j)
# Found a bigger one :  (25448.3340077+99.4458286071j)
# Found a bigger one :  (25448.3340321+99.4458308799j)
# Found a bigger one :  (25448.3340855+99.4458406489j)
# ---------------------
# 8 ; 140.413745031 99.4458406489
# ---------------------
# 000009000000nmacro1_nBin333_Idc2.50A_ThetaL-1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20303.97530997]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25455.1685627+100.220212109j)
# Found a bigger one :  (25455.168568+100.220212933j)
# Found a bigger one :  (25455.1685694+100.220213155j)
# Found a bigger one :  (25455.1686029+100.220218339j)
# Found a bigger one :  (25455.1686317+100.22022279j)
# ---------------------
# 9 ; 141.501496832 100.22022279
# ---------------------
# 000010000000nmacro1_nBin333_Idc2.50A_ThetaL0.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20425.68058711]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25462.0163289+100.997855522j)
# Found a bigger one :  (25462.0163361+100.997856632j)
# Found a bigger one :  (25462.0163596+100.997860259j)
# Found a bigger one :  (25462.0163653+100.997861136j)
# Found a bigger one :  (25462.0163797+100.997863391j)
# Found a bigger one :  (25462.0164507+100.997872844j)
# ---------------------
# 10 ; 142.591361081 100.997872844
# ---------------------
# 000011000000nmacro1_nBin333_Idc2.50A_ThetaL1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20547.38582677]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25468.8815227+101.779253863j)
# Found a bigger one :  (25468.8815686+101.779260966j)
# Found a bigger one :  (25468.8815756+101.779262047j)
# Found a bigger one :  (25468.881576+101.779262109j)
# Found a bigger one :  (25468.8815778+101.779262396j)
# Found a bigger one :  (25468.881579+101.779262576j)
# Found a bigger one :  (25468.8816267+101.779269976j)
# Found a bigger one :  (25468.8817061+101.779280586j)
# Found a bigger one :  (25468.8817005+101.779281458j)
# ---------------------
# 11 ; 143.683999525 101.779281458
# ---------------------
# 000012000000nmacro1_nBin333_Idc2.50A_ThetaL2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20669.16521358]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25475.7686017+102.564942269j)
# Found a bigger one :  (25475.7686914+102.564956182j)
# Found a bigger one :  (25475.768701+102.564957639j)
# Found a bigger one :  (25475.7687093+102.564958909j)
# Found a bigger one :  (25475.7687166+102.564960094j)
# Found a bigger one :  (25475.7687428+102.564964153j)
# Found a bigger one :  (25475.7687761+102.564969325j)
# ---------------------
# 12 ; 144.780111646 102.564969325
# ---------------------
# 000013000000nmacro1_nBin333_Idc2.50A_ThetaL3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20791.09311295]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25482.6819883+103.355453015j)
# Found a bigger one :  (25482.6819976+103.355454335j)
# Found a bigger one :  (25482.6819965+103.35545465j)
# Found a bigger one :  (25482.6821498+103.35547802j)
# ---------------------
# 13 ; 145.880409235 103.35547802
# ---------------------
# 000014000000nmacro1_nBin333_Idc2.50A_ThetaL4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20913.24425352]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25489.6260802+104.151316287j)
# Found a bigger one :  (25489.6260803+104.151316301j)
# Found a bigger one :  (25489.6260829+104.151316699j)
# Found a bigger one :  (25489.6260878+104.151317294j)
# Found a bigger one :  (25489.6261196+104.151322401j)
# Found a bigger one :  (25489.6261258+104.151323363j)
# Found a bigger one :  (25489.6262757+104.151346747j)
# Found a bigger one :  (25489.6263105+104.151349154j)
# ---------------------
# 14 ; 146.985606736 104.151349154
# ---------------------
# 000015000000nmacro1_nBin333_Idc2.50A_ThetaL5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21035.69391024]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25496.605465+104.953094272j)
# Found a bigger one :  (25496.6054738+104.953095642j)
# Found a bigger one :  (25496.6054777+104.953096453j)
# Found a bigger one :  (25496.605523+104.953103329j)
# Found a bigger one :  (25496.6055258+104.953103773j)
# Found a bigger one :  (25496.6057822+104.953139753j)
# ---------------------
# 15 ; 148.096424167 104.953139753
# ---------------------
# 000016000000nmacro1_nBin333_Idc2.50A_ThetaL6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21158.5180915]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25503.6248315+105.761366037j)
# Found a bigger one :  (25503.6248316+105.76136605j)
# Found a bigger one :  (25503.6248318+105.761366078j)
# Found a bigger one :  (25503.6248326+105.761366178j)
# Found a bigger one :  (25503.6248477+105.761368571j)
# Found a bigger one :  (25503.6248843+105.761374277j)
# Found a bigger one :  (25503.6249856+105.761387168j)
# Found a bigger one :  (25503.6252207+105.761421837j)
# ---------------------
# 16 ; 149.213602505 105.761421837
# ---------------------
# 000017000000nmacro1_nBin333_Idc2.50A_ThetaL7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21281.79372925]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25510.6889101+106.576718504j)
# Found a bigger one :  (25510.6889154+106.576719343j)
# Found a bigger one :  (25510.6889276+106.57672124j)
# Found a bigger one :  (25510.6889309+106.576721751j)
# Found a bigger one :  (25510.6889475+106.576724346j)
# Found a bigger one :  (25510.6889484+106.576724472j)
# Found a bigger one :  (25510.6889615+106.576726552j)
# Found a bigger one :  (25510.6890199+106.576734329j)
# Found a bigger one :  (25510.6891825+106.576755966j)
# ---------------------
# 17 ; 150.337866934 106.576755966
# ---------------------
# 000018000000nmacro1_nBin333_Idc2.50A_ThetaL8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21405.59887499]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25517.8026024+107.399766328j)
# Found a bigger one :  (25517.8026041+107.399766585j)
# Found a bigger one :  (25517.8026356+107.399771516j)
# Found a bigger one :  (25517.8026513+107.399773972j)
# Found a bigger one :  (25517.8026541+107.399774405j)
# Found a bigger one :  (25517.8026557+107.399774665j)
# Found a bigger one :  (25517.8028079+107.39979847j)
# Found a bigger one :  (25517.802918+107.3998087j)
# ---------------------
# 18 ; 151.470053111 107.3998087
# ---------------------
# 000019000000nmacro1_nBin333_Idc2.50A_ThetaL9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21530.01290041]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  1 , 1
# Found a bigger one :  (25524.9708977+108.231138524j)
# Found a bigger one :  (25524.9709164+108.231141454j)
# Found a bigger one :  (25524.9709191+108.231141878j)
# Found a bigger one :  (25524.9709307+108.2311437j)
# Found a bigger one :  (25524.9711045+108.231170951j)
# ---------------------
# 19 ; 152.610905417 108.231170951
# ---------------------
# 000000000000nmacro1_nBin333_Idc2.50A_ThetaL-10.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19196.24063283]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24503.9212907-3.3381583806j)
# Found a bigger one :  (24503.9212913-3.33815760046j)
# Found a bigger one :  (24503.9212913-3.33815751672j)
# Found a bigger one :  (24503.9212914-3.33815751618j)
# Found a bigger one :  (24503.9212942-3.33815403284j)
# Found a bigger one :  (24503.9212981-3.33815310951j)
# ---------------------
# 0 ; -9.89421840986 -3.33815310951
# ---------------------
# 000001000000nmacro1_nBin333_Idc2.50A_ThetaL-9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19321.34517914]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24504.2102803-3.27350033965j)
# ---------------------
# 1 ; -9.84822546348 -3.27350033965
# ---------------------
# 000002000000nmacro1_nBin333_Idc2.50A_ThetaL-8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19445.75986254]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24504.4940836-3.21084761202j)
# Found a bigger one :  (24504.4940843-3.2108466243j)
# Found a bigger one :  (24504.494084-3.21084564137j)
# Found a bigger one :  (24504.4940899-3.21084233925j)
# Found a bigger one :  (24504.494086-3.21084167582j)
# ---------------------
# 2 ; -9.8030563908 -3.21084167582
# ---------------------
# 000003000000nmacro1_nBin333_Idc2.50A_ThetaL-7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19569.56558514]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24504.7730208-3.15007057403j)
# Found a bigger one :  (24504.7730213-3.15006985051j)
# Found a bigger one :  (24504.7730214-3.15006977835j)
# Found a bigger one :  (24504.7730214-3.15006977549j)
# Found a bigger one :  (24504.7730219-3.15006802632j)
# Found a bigger one :  (24504.7730245-3.15006736716j)
# Found a bigger one :  (24504.7730241-3.15006653279j)
# Found a bigger one :  (24504.7730277-3.1500648344j)
# Found a bigger one :  (24504.7730232-3.15006415784j)
# ---------------------
# 3 ; -9.75866215208 -3.15006415784
# ---------------------
# 000004000000nmacro1_nBin333_Idc2.50A_ThetaL-6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19692.84172004]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24505.0473736-3.09106363016j)
# Found a bigger one :  (24505.0473736-3.09106360489j)
# Found a bigger one :  (24505.0473742-3.09106311015j)
# Found a bigger one :  (24505.0473731-3.09106225615j)
# Found a bigger one :  (24505.0473753-3.09106153778j)
# Found a bigger one :  (24505.0473763-3.09106030125j)
# Found a bigger one :  (24505.0473804-3.0910583163j)
# ---------------------
# 4 ; -9.71499684544 -3.0910583163
# ---------------------
# 000005000000nmacro1_nBin333_Idc2.50A_ThetaL-5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19815.66631979]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24505.3174127-3.03372742371j)
# Found a bigger one :  (24505.3174134-3.03372663039j)
# Found a bigger one :  (24505.3174134-3.03372662589j)
# Found a bigger one :  (24505.3174134-3.03372660039j)
# Found a bigger one :  (24505.3174133-3.03372617353j)
# Found a bigger one :  (24505.3174156-3.03372442169j)
# Found a bigger one :  (24505.3174154-3.0337243279j)
# Found a bigger one :  (24505.3174175-3.03372398266j)
# ---------------------
# 5 ; -9.67201910356 -3.03372398266
# ---------------------
# 000006000000nmacro1_nBin333_Idc2.50A_ThetaL-4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19938.11631757]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24505.5833999-2.97796419948j)
# Found a bigger one :  (24505.5833999-2.97796418544j)
# Found a bigger one :  (24505.5834019-2.97796178868j)
# Found a bigger one :  (24505.5834046-2.97795871928j)
# ---------------------
# 6 ; -9.62968594618 -2.97795871928
# ---------------------
# 000007000000nmacro1_nBin333_Idc2.50A_ThetaL-3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20060.26772255]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24505.8455789-2.92368891402j)
# Found a bigger one :  (24505.8455796-2.92368821087j)
# Found a bigger one :  (24505.8455797-2.92368802743j)
# Found a bigger one :  (24505.8455797-2.9236880252j)
# Found a bigger one :  (24505.8455797-2.92368801651j)
# Found a bigger one :  (24505.8455797-2.92368801508j)
# Found a bigger one :  (24505.8455799-2.92368772845j)
# Found a bigger one :  (24505.8455821-2.92368653687j)
# Found a bigger one :  (24505.8455819-2.92368537075j)
# ---------------------
# 7 ; -9.5879591298 -2.92368537075
# ---------------------
# 000008000000nmacro1_nBin333_Idc2.50A_ThetaL-2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20182.19581044]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24506.104188-2.87081568318j)
# Found a bigger one :  (24506.104188-2.87081559654j)
# Found a bigger one :  (24506.1041883-2.87081531698j)
# Found a bigger one :  (24506.1041916-2.87081371264j)
# Found a bigger one :  (24506.1041904-2.87081291502j)
# Found a bigger one :  (24506.1041905-2.87081271476j)
# ---------------------
# 8 ; -9.54680029015 -2.87081271476
# ---------------------
# 000009000000nmacro1_nBin333_Idc2.50A_ThetaL-1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20303.97530997]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24506.3594489-2.81927074502j)
# Found a bigger one :  (24506.3594495-2.81927002078j)
# Found a bigger one :  (24506.3594542-2.81926647217j)
# Found a bigger one :  (24506.3594535-2.81926536464j)
# Found a bigger one :  (24506.3594545-2.81926455383j)
# ---------------------
# 9 ; -9.50617376129 -2.81926455383
# ---------------------
# 000010000000nmacro1_nBin333_Idc2.50A_ThetaL0.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20425.68058711]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24506.6115787-2.76897966109j)
# Found a bigger one :  (24506.6115793-2.76897887275j)
# Found a bigger one :  (24506.6115794-2.76897887165j)
# Found a bigger one :  (24506.6115811-2.76897691395j)
# Found a bigger one :  (24506.6115812-2.7689766525j)
# Found a bigger one :  (24506.6115835-2.76897653591j)
# Found a bigger one :  (24506.6115863-2.76897382044j)
# ---------------------
# 10 ; -9.46604574431 -2.76897382044
# ---------------------
# 000011000000nmacro1_nBin333_Idc2.50A_ThetaL1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20547.38582677]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24506.8607843-2.7198723075j)
# Found a bigger one :  (24506.8607858-2.71987216263j)
# Found a bigger one :  (24506.8607861-2.71987167385j)
# Found a bigger one :  (24506.8607878-2.71986962187j)
# Found a bigger one :  (24506.8607912-2.71986909678j)
# ---------------------
# 11 ; -9.42638355829 -2.71986909678
# ---------------------
# 000012000000nmacro1_nBin333_Idc2.50A_ThetaL2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20669.16521358]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24507.1072605-2.67189334149j)
# Found a bigger one :  (24507.1072605-2.67189334149j)
# Found a bigger one :  (24507.1072623-2.67189136822j)
# Found a bigger one :  (24507.107266-2.67188916069j)
# Found a bigger one :  (24507.1072646-2.67188838796j)
# ---------------------
# 12 ; -9.38715608733 -2.67188838796
# ---------------------
# 000013000000nmacro1_nBin333_Idc2.50A_ThetaL3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20791.09311295]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24507.3511996-2.62497649318j)
# Found a bigger one :  (24507.3512003-2.62497563724j)
# Found a bigger one :  (24507.3512038-2.62497348581j)
# Found a bigger one :  (24507.3512027-2.62497299108j)
# Found a bigger one :  (24507.3512096-2.62496871343j)
# ---------------------
# 13 ; -9.34833104867 -2.62496871343
# ---------------------
# 000014000000nmacro1_nBin333_Idc2.50A_ThetaL4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20913.24425352]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24507.5927892-2.57906258886j)
# Found a bigger one :  (24507.5927895-2.57906219117j)
# Found a bigger one :  (24507.5927961-2.57905831128j)
# ---------------------
# 14 ; -9.30988135074 -2.57905831128
# ---------------------
# 000015000000nmacro1_nBin333_Idc2.50A_ThetaL5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21035.69391024]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24507.8321974-2.5341091064j)
# Found a bigger one :  (24507.8321991-2.53410725165j)
# Found a bigger one :  (24507.8322021-2.53410636901j)
# Found a bigger one :  (24507.8321982-2.53410489617j)
# ---------------------
# 15 ; -9.27177932605 -2.53410489617
# ---------------------
# 000016000000nmacro1_nBin333_Idc2.50A_ThetaL6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21158.5180915]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24508.0696031-2.49005806068j)
# Found a bigger one :  (24508.0696037-2.49005735834j)
# Found a bigger one :  (24508.0696042-2.49005706901j)
# Found a bigger one :  (24508.0696046-2.49005639144j)
# Found a bigger one :  (24508.0696123-2.49005108759j)
# ---------------------
# 16 ; -9.23399369432 -2.49005108759
# ---------------------
# 000017000000nmacro1_nBin333_Idc2.50A_ThetaL7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21281.79372925]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24508.3051716-2.44686356065j)
# Found a bigger one :  (24508.3051722-2.44686283161j)
# Found a bigger one :  (24508.3051769-2.44685941546j)
# Found a bigger one :  (24508.3051737-2.44685768214j)
# ---------------------
# 17 ; -9.19650294255 -2.44685768214
# ---------------------
# 000018000000nmacro1_nBin333_Idc2.50A_ThetaL8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21405.59887499]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24508.5390641-2.4044816545j)
# Found a bigger one :  (24508.5390646-2.4044809575j)
# Found a bigger one :  (24508.5390675-2.40447879196j)
# Found a bigger one :  (24508.5390677-2.4044775297j)
# ---------------------
# 18 ; -9.1592775498 -2.4044775297
# ---------------------
# 000019000000nmacro1_nBin333_Idc2.50A_ThetaL9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21530.01290041]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 0
# Found a bigger one :  (24508.7714383-2.36286957048j)
# Found a bigger one :  (24508.7714389-2.36286743872j)
# Found a bigger one :  (24508.7714436-2.36286580406j)
# ---------------------
# 19 ; -9.12229378457 -2.36286580406
# ---------------------
# 000000000000nmacro1_nBin333_Idc2.50A_ThetaL-10.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19196.24063283]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24551.9144102+0.319140323465j)
# Found a bigger one :  (24551.9144102+0.31914032391j)
# Found a bigger one :  (24551.9144105+0.319140348368j)
# Found a bigger one :  (24551.9144105+0.31914034977j)
# ---------------------
# 0 ; -2.25587733041 0.31914034977
# ---------------------
# 000001000000nmacro1_nBin333_Idc2.50A_ThetaL-9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19321.34517914]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24551.9380067+0.321819989827j)
# Found a bigger one :  (24551.9380067+0.321819989977j)
# Found a bigger one :  (24551.9380067+0.321819991867j)
# Found a bigger one :  (24551.9380067+0.321819998667j)
# Found a bigger one :  (24551.9380068+0.321819998689j)
# Found a bigger one :  (24551.9380067+0.321820001986j)
# Found a bigger one :  (24551.9380069+0.321820004816j)
# Found a bigger one :  (24551.938007+0.321820009038j)
# ---------------------
# 1 ; -2.25212184524 0.321820009038
# ---------------------
# 000002000000nmacro1_nBin333_Idc2.50A_ThetaL-8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19445.75986254]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24551.9615351+0.32449809997j)
# Found a bigger one :  (24551.9615351+0.324498100421j)
# Found a bigger one :  (24551.9615352+0.324498121652j)
# Found a bigger one :  (24551.9615355+0.324498126284j)
# ---------------------
# 2 ; -2.24837716306 0.324498126284
# ---------------------
# 000003000000nmacro1_nBin333_Idc2.50A_ThetaL-7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19569.56558514]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24551.9850104+0.327176332885j)
# Found a bigger one :  (24551.9850107+0.327176354171j)
# Found a bigger one :  (24551.9850106+0.327176355868j)
# ---------------------
# 3 ; -2.24464097571 0.327176355868
# ---------------------
# 000004000000nmacro1_nBin333_Idc2.50A_ThetaL-6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19692.84172004]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.0084473+0.329856366979j)
# Found a bigger one :  (24552.0084473+0.329856367574j)
# Found a bigger one :  (24552.0084473+0.329856373749j)
# Found a bigger one :  (24552.0084474+0.329856377587j)
# Found a bigger one :  (24552.0084474+0.329856379282j)
# Found a bigger one :  (24552.0084475+0.329856385392j)
# Found a bigger one :  (24552.0084475+0.329856385394j)
# ---------------------
# 4 ; -2.24091088379 0.329856385394
# ---------------------
# 000005000000nmacro1_nBin333_Idc2.50A_ThetaL-5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19815.66631979]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.0318604+0.332539884345j)
# Found a bigger one :  (24552.0318604+0.332539884787j)
# Found a bigger one :  (24552.0318606+0.332539902943j)
# Found a bigger one :  (24552.0318606+0.332539904132j)
# ---------------------
# 5 ; -2.23718456648 0.332539904132
# ---------------------
# 000006000000nmacro1_nBin333_Idc2.50A_ThetaL-4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-19938.11631757]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.0552645+0.335228575062j)
# Found a bigger one :  (24552.0552645+0.335228575667j)
# Found a bigger one :  (24552.0552647+0.33522859272j)
# Found a bigger one :  (24552.0552645+0.335228595023j)
# Found a bigger one :  (24552.0552647+0.33522859759j)
# ---------------------
# 6 ; -2.23345969106 0.33522859759
# ---------------------
# 000007000000nmacro1_nBin333_Idc2.50A_ThetaL-3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20060.26772255]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.078674+0.337924141576j)
# Found a bigger one :  (24552.078674+0.337924141591j)
# Found a bigger one :  (24552.0786742+0.337924159386j)
# Found a bigger one :  (24552.0786742+0.33792416168j)
# ---------------------
# 7 ; -2.22973395736 0.33792416168
# ---------------------
# 000008000000nmacro1_nBin333_Idc2.50A_ThetaL-2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20182.19581044]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.1021036+0.340628303019j)
# Found a bigger one :  (24552.1021036+0.340628303614j)
# Found a bigger one :  (24552.1021038+0.340628320915j)
# Found a bigger one :  (24552.1021038+0.340628323255j)
# ---------------------
# 8 ; -2.22600502065 0.340628323255
# ---------------------
# 000009000000nmacro1_nBin333_Idc2.50A_ThetaL-1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20303.97530997]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.1255679+0.343342799662j)
# Found a bigger one :  (24552.1255679+0.343342799772j)
# Found a bigger one :  (24552.1255681+0.3433428177j)
# Found a bigger one :  (24552.1255681+0.343342817754j)
# Found a bigger one :  (24552.1255682+0.343342826703j)
# ---------------------
# 9 ; -2.222270552 0.343342826703
# ---------------------
# 000010000000nmacro1_nBin333_Idc2.50A_ThetaL0.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20425.68058711]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.1490817+0.34606939764j)
# Found a bigger one :  (24552.1490817+0.346069398241j)
# Found a bigger one :  (24552.1490818+0.346069399766j)
# Found a bigger one :  (24552.1490818+0.346069407817j)
# Found a bigger one :  (24552.1490818+0.346069407839j)
# Found a bigger one :  (24552.1490819+0.346069410561j)
# Found a bigger one :  (24552.1490819+0.346069414659j)
# Found a bigger one :  (24552.1490819+0.346069418165j)
# ---------------------
# 10 ; -2.21852821885 0.346069418165
# ---------------------
# 000011000000nmacro1_nBin333_Idc2.50A_ThetaL1.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20547.38582677]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.1726599+0.348809893544j)
# Found a bigger one :  (24552.1726599+0.348809893976j)
# Found a bigger one :  (24552.1726599+0.348809895659j)
# Found a bigger one :  (24552.17266+0.348809902974j)
# Found a bigger one :  (24552.17266+0.348809903811j)
# Found a bigger one :  (24552.17266+0.348809909627j)
# Found a bigger one :  (24552.1726601+0.348809915418j)
# ---------------------
# 11 ; -2.21477564306 0.348809915418
# ---------------------
# 000012000000nmacro1_nBin333_Idc2.50A_ThetaL2.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20669.16521358]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.1963173+0.351566119372j)
# Found a bigger one :  (24552.1963173+0.351566119815j)
# Found a bigger one :  (24552.1963173+0.351566121157j)
# Found a bigger one :  (24552.1963174+0.351566128868j)
# Found a bigger one :  (24552.1963174+0.351566129722j)
# Found a bigger one :  (24552.1963175+0.351566135566j)
# Found a bigger one :  (24552.1963175+0.35156613664j)
# Found a bigger one :  (24552.1963175+0.351566137824j)
# Found a bigger one :  (24552.1963175+0.351566144824j)
# ---------------------
# 12 ; -2.21101044297 0.351566144824
# ---------------------
# 000013000000nmacro1_nBin333_Idc2.50A_ThetaL3.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20791.09311295]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.2200694+0.354339947656j)
# Found a bigger one :  (24552.2200694+0.354339948255j)
# Found a bigger one :  (24552.2200695+0.354339966217j)
# Found a bigger one :  (24552.2200695+0.35433996946j)
# ---------------------
# 13 ; -2.20723019696 0.35433996946
# ---------------------
# 000014000000nmacro1_nBin333_Idc2.50A_ThetaL4.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-20913.24425352]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.2439314+0.357133296662j)
# Found a bigger one :  (24552.2439314+0.357133297261j)
# Found a bigger one :  (24552.2439316+0.357133325933j)
# ---------------------
# 14 ; -2.20343242264 0.357133325933
# ---------------------
# 000015000000nmacro1_nBin333_Idc2.50A_ThetaL5.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21035.69391024]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.2679192+0.359948136071j)
# Found a bigger one :  (24552.2679192+0.359948136665j)
# Found a bigger one :  (24552.2679193+0.359948154878j)
# Found a bigger one :  (24552.2679193+0.359948156096j)
# Found a bigger one :  (24552.2679194+0.359948157023j)
# ---------------------
# 15 ; -2.19961465509 0.359948157023
# ---------------------
# 000016000000nmacro1_nBin333_Idc2.50A_ThetaL6.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21158.5180915]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.2920488+0.362786492779j)
# Found a bigger one :  (24552.2920488+0.362786493393j)
# Found a bigger one :  (24552.2920489+0.362786511738j)
# Found a bigger one :  (24552.292049+0.362786512668j)
# Found a bigger one :  (24552.292049+0.362786513803j)
# ---------------------
# 16 ; -2.19577430077 0.362786513803
# ---------------------
# 000017000000nmacro1_nBin333_Idc2.50A_ThetaL7.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21281.79372925]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.3163367+0.36565045719j)
# Found a bigger one :  (24552.3163367+0.365650457784j)
# Found a bigger one :  (24552.3163368+0.365650476252j)
# Found a bigger one :  (24552.3163368+0.36565048003j)
# ---------------------
# 17 ; -2.19190877542 0.36565048003
# ---------------------
# 000018000000nmacro1_nBin333_Idc2.50A_ThetaL8.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21405.59887499]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.3407997+0.368542189617j)
# Found a bigger one :  (24552.3407997+0.368542190215j)
# Found a bigger one :  (24552.3407997+0.368542199452j)
# Found a bigger one :  (24552.3407997+0.368542200342j)
# Found a bigger one :  (24552.3407998+0.368542207608j)
# Found a bigger one :  (24552.3407998+0.368542212617j)
# Found a bigger one :  (24552.3407998+0.368542213866j)
# ---------------------
# 18 ; -2.18801537506 0.368542213866
# ---------------------
# 000019000000nmacro1_nBin333_Idc2.50A_ThetaL9.0degree_delay0.000us_gain0.00_0.00
# Qs:  0.05
# dfc:  [-21530.01290041]
# NperBunch:  3.16740012699
# nBunch:  630
# Current mode :  2 , 1
# Found a bigger one :  (24552.3654551+0.371463927409j)
# Found a bigger one :  (24552.3654551+0.371463928026j)
# Found a bigger one :  (24552.3654552+0.371463954792j)
# Found a bigger one :  (24552.3654555+0.371463957712j)
# ---------------------
# 19 ; -2.18409129065 0.371463957712
# ---------------------

# %%
os.chdir(working_folder)
for m in ms:
    for mu in mus:
        pd.DataFrame(delta_omega_Im_Iter[m][mu]).to_csv("OmegaIM_"+str(m)+'_'+str(mu)+'.txt')
        pd.DataFrame(delta_omega_Re_Iter[m][mu]).to_csv("OmegaRE_"+str(m)+'_'+str(mu)+'.txt')

# %%
QL
# Out:
# [56520.538659366175]

# %%
IbDC = 1.6e-19*nBunch*NperBunch*f0
R = np.array(RoQ)*np.array(QL)
Vbr = IbDC*2*R
phis = np.abs(np.arctan(np.array(V0)/np.array(V0Q)))
Vc = np.sqrt(np.array(V0Q)**2+np.array(V0)**2)
f = f0*h[0]
df1 = -(Vbr*np.sin(phis)/Vc+np.tan(thetaL1/180*pi)*(1+Vbr/Vc*np.cos(phis)))*f/2/QL
df1_opt = -(Vbr*np.sin(phis)/Vc+np.tan(0/180*pi)*(1+Vbr/Vc*np.cos(phis)))*f/2/QL
fig1,axes1 = plt.subplots(N_m,N_mode)
fig1.set_figheight(8*N_mode)
fig1.set_figwidth(8*N_m)

damp = 1/t_rad_long*1
for m in ms:
    for mu in mus:
        axes1[m][mu].plot(df1,pd.DataFrame(delta_omega_Im_Iter[m][mu])-damp,'.-')
        axes1[m][mu].set_title("Map of Omega_Im "+str(m)+'_'+str(mu))
        axes1[m][mu].set_ylabel('Omega_'+str(m+1)+'_'+str(mu)+'_Im (Hz)',fontsize=10)
        axes1[m][mu].set_xlabel('df_1 (Hz)',fontsize=10)
        axes1[m][mu].axhline(y=0,color='r')
        axes1[m][mu].axvline(x=df1_opt)
fn_stab = os.path.join(cwd,'stability_map.jpg')
plt.savefig(fn_stab,bbox_inches='tight')
plt.show()

# %%
R
# Out:
# array([29632392.6719072])

# %%
RoQ
# Out:
# [1022.0]

# %%
V0
# Out:
# [22812782.9976]

# %%
V0Q
# Out:
# [-3600000.0]

# %%
df1
# Out:
# array([110095.12561445,  41340.30106029,  70638.40872817, 212121.68787188,
#         51557.40755171,  77723.36870485, -74030.8909001 ,  58583.79257943,
#         88103.61089311,  19992.91071985,  64513.03540066, 109033.16008146,
#         40922.4599082 ,  70442.27822188, 203056.96170141,  51302.70209647,
#         77468.66324961, -83095.61707056,  58387.66207315,  87685.76974102])

# %%
phis
# Out:
# array([1.41428077])
